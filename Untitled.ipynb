# %%
import os
from dotenv import load_dotenv
from huggingface_hub import HfApi

print("Répertoire courant:", os.getcwd())
env_path = os.path.join(os.getcwd(), '.env')
print(f"\nCherche .env dans: {env_path}")
print(f"Le fichier existe: {os.path.exists(env_path)}")
# Out:
# Répertoire courant: /home/veron/projetInfo/modetrend
#
# Cherche .env dans: /home/veron/projetInfo/modetrend/.env
# Le fichier existe: True

# %%
hf_token = os.getenv('HF_TOKEN)')

if os.path.exists(env_path):
    with open(env_path, 'r') as f:
        content = f.read()
        if 'HF_TOKEN' in content:
            print("✓ HF_TOKEN trouvé dans .env")
        else:
            print("✗ HF_TOKEN non trouvé dans .env")
else:
    print("✗ Fichier .env introuvable")
# Out:
# ✓ HF_TOKEN trouvé dans .env
